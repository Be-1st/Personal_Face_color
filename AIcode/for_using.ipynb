# %%
# prompt: googlemount

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
import os

# 변경할 작업 디렉토리 경로
new_working_directory = '/content/drive/MyDrive/1st/Color-insight/src'

# 작업 디렉토리 변경
os.chdir(new_working_directory)

# 변경된 작업 디렉토리 확인
print("현재 작업 디렉토리:", os.getcwd())
# Out:
# 현재 작업 디렉토리: /content/drive/MyDrive/1st/Color-insight/src

# %%
# %pip install colormath
# Out:
# Collecting colormath
#   Downloading colormath-3.0.0.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from colormath) (1.25.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from colormath) (3.3)
# Building wheels for collected packages: colormath
#   Building wheel for colormath (setup.py) ... done
#   Created wheel for colormath: filename=colormath-3.0.0-py3-none-any.whl size=39407 sha256=66f04970eefdfd73a9b76f36da7a53949e753c29f9f02e739935b60ff1947fbf
#   Stored in directory: /root/.cache/pip/wheels/ab/b3/4d/c0738759c25a1df01958068f162cf2a9dc3ab1da8b972cfcfc
# Successfully built colormath
# Installing collected packages: colormath
# Successfully installed colormath-3.0.0

# %%
import argparse
import os

# 인자값 받을 인스턴스 생성
parser = argparse.ArgumentParser(description='Please input your image.')

# 입력받을 인자값 등록
parser.add_argument('--image', required=False, help='input .jpg or .png file')
parser.add_argument('--dir', required=False, help='input image directory')

# 수정된 부분: 추가 인자를 무시하도록 설정
args, unknown = parser.parse_known_args()

##################################
#         a single image         #
##################################
if args.image is not None:
    imgpath = args.image
    personal_color.analysis(imgpath)

##################################
#  multiple images in directory  #
##################################
elif args.dir is not None:
    dirpath = args.dir
    imgs = os.listdir(dirpath)
    for imgpath in imgs:
        personal_color.analysis(os.path.join(dirpath, imgpath))

# %%
from personal_color_analysis import personal_color
import argparse
import os


# 인자값 받을 인스턴스 생성
parser = argparse.ArgumentParser(description = 'Please input your image.')

# 입력받을 인자값 등록
parser.add_argument('--image', required = False, help='input .jpg or .png file')
parser.add_argument('--dir', required = False, help='input image directory')

# 입력받은 인자값을 args에 저장
args = parser.parse_args()

##################################
#         a single image         #
##################################
if args.image != None:
    imgpath = args.image
    personal_color.analysis(imgpath)

##################################
#  multiple images in directory  #
##################################
elif args.dir != None:
    dirpath = args.dir
    imgs = os.listdir(dirpath)
    for imgpath in imgs:
        #print(os.path.join(dirpath, imgpath))
        personal_color.analysis(os.path.join(dirpath, imgpath))
# Out:
# usage: colab_kernel_launcher.py [-h] [--image IMAGE] [--dir DIR]
# colab_kernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-2f41827d-a9eb-4756-99cc-5291c8d88b7a.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
# !python main.py --image '/content/drive/MyDrive/1st/Color-insight/res/test/nfall/1.jpg'
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# Lab_b[skin, eyebrow, eye] [20.37, 22.26, 11.21]
# hsv_s[skin, eyebrow, eye] [32.0, 59.0, 28.999999999999996]
# skin 의 spring 기준값과의 거리
# 134.07039999999998
# skin 의 fall 기준값과의 거리
# 48.601300000000016
# eyebrow 의 spring 기준값과의 거리
# 28.69697
# eyebrow 의 fall 기준값과의 거리
# 19.24845
# eye 의 spring 기준값과의 거리
# 3.193549999999995
# eye 의 fall 기준값과의 거리
# 8.500000000000004
# /content/drive/MyDrive/1st/Color-insight/res/test/nfall/1.jpg의 퍼스널 컬러는 가을웜톤(fall)입니다.
