# %%
import os
os.getcwd()
# Out:
# 'c:\\dlib-19.24\\Color-insight\\src'

# %%
# import os

# # 변경할 작업 디렉토리 경로
# new_working_directory = r'C:\Users\Daehee'

# # 작업 디렉토리 변경
# os.chdir(new_working_directory)

# # 변경된 작업 디렉토리 확인
# print("현재 작업 디렉토리:", os.getcwd())

# %%
os.getcwd()
# Out:
# 'c:\\dlib-19.24\\Color-insight\\src'

# %%
import dlib
print(dlib.__version__)
# Out:
# 19.24.4

# %%
# !python "C:\dlib-19.24\Color-insight\src\main.py" --image "C:\dlib-19.24\Color-insight\res\test\nfall\2.jpg"
# Out:
# Lab_b[skin, eyebrow, eye] [11.7, 5.9, 11.81]
# hsv_s[skin, eyebrow, eye] [31.0, 35.0, 55.00000000000001]
# skin 의 spring 기준값과의 거리
# 124.07039999999998
# skin 의 fall 기준값과의 거리
# 38.601300000000016
# eyebrow 의 spring 기준값과의 거리
# 4.69697
# eyebrow 의 fall 기준값과의 거리
# 4.751550000000002
# eye 의 spring 기준값과의 거리
# 29.193550000000005
# eye 의 fall 기준값과의 거리
# 17.500000000000007
# C:\dlib-19.24\Color-insight\res\test\nfall\2.jpg의 퍼스널 컬러는 가을웜톤(fall)입니다.

# %% [markdown]
# ## Flask로 웹페이지 만들어보기

# %%
# !pip install Flask
